# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# **Objectives:**
# * List popular languages for Data Science
# * List commonly used libraries by Data Scientists
# * List commonly used Data Science tools
# * Display skills using markdown syntax
# * Display basic python skills
# * Display skills with Jupyter Noteboosks

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, common data science tools, languages, and libraries are listed along with code to prove competency for "Tools for Data Science" final assignment

# %% [markdown]
# Some of the popular languages that Data Scienctists use are:
# 1. SQL
# 2. Python
# 3. R
# 4. Scala
# 5. Java
# 6. Julia

# %% [markdown]
# Some of the commonly used libraries by Data Scientists include the following:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. Sckit-learn
# 6. Keras
# 7. PyTorch

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | Juptyer Lab |
# | Anaconda |
# | VS Code |

# %% [markdown]
# ### The following code segments are examples of evaluating expressions in Python

# %%
#The following line is an arthimetic expression to multiply 2 integers then add another
(3*4)+5
# Out:
# 17

# %%
#The following line will calculate how many hours is 200 minutes
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Sean Kunstman
